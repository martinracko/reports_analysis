# %% [markdown]
# # Crawler Excavators 2015 Pre-analysis

# %% [markdown]
# Duplicates included for portal overviews, excluded for category class overviews, listings + auctions mapped to model reliably from Europe. Based on ~73K records (~43K w/o duplicates).

# %%
import json
records = [json.loads(line) for line in open('excavators_dup.json')]
from pandas import DataFrame, Series
import pandas as pd; import numpy as np
import matplotlib as plt
plt.rcParams['figure.figsize'] = (10,5)
plt.rcParams['savefig.dpi'] = 100

# %%
frame = DataFrame(records)
frame.c = frame.c.astype(float64)
idx = pd.Index([u'2010Q1', u'2010Q2', u'2010Q3', u'2010Q4', \
                u'2011Q1', u'2011Q2', u'2011Q3', u'2011Q4', \
                u'2012Q1', u'2012Q2', u'2012Q3', u'2012Q4', \
                u'2013Q1', u'2013Q2', u'2013Q3', u'2013Q4', \
                u'2014Q1', u'2014Q2', u'2014Q3'])

# %% [markdown]
# ## Portal Breakdown

# %%
by_p = frame.groupby(['portal', frame['auction']])
agg_counts = (by_p.size().unstack().fillna(0))
agg_counts.plot(kind='barh', stacked=True)

# %% [markdown]
# ## Minutemachine by Quarters

# %%
frame[frame.portal == 'minutemachine'].groupby('q').size().reindex(idx, fill_value=0).plot(kind='bar', stacked=True)

# %% [markdown]
# ## Mascus by Quarters

# %%
frame[frame.portal == 'mascus'].groupby('q').size().reindex(idx, fill_value=0).plot(kind='bar', stacked=True)

# %% [markdown]
# ## Machineryzone by Quarters

# %%
frame[frame.portal == 'machineryzone'].groupby('q').size().reindex(idx, fill_value=0).plot(kind='bar', stacked=True)

# %% [markdown]
# ## Machinerypark by Quarters

# %% [markdown]
# Bauportal + Bau-portal + Machinerypark all together.

# %%
frame[frame.portal == 'machinerypark'].groupby('q').size().reindex(idx, fill_value=0).plot(kind='bar', stacked=True)

# %% [markdown]
# ## RB Auctions by Quarters

# %%
frame[frame.portal == 'ritchiebrosauctioneers'].groupby('q').size().reindex(idx, fill_value=0).plot(kind='bar', stacked=True)

# %% [markdown]
# ## Autoline by Quarters

# %%
frame[frame.portal == 'autoline'].groupby('q').size().reindex(idx, fill_value=0).plot(kind='bar', stacked=True)

# %% [markdown]
# ## Marketbook by Quarters

# %%
frame[frame.portal == 'marketbook'].groupby('q').size().reindex(idx, fill_value=0).plot(kind='bar', stacked=True)

# %% [markdown]
# ## All Crawler Excavators

# %%
records = [json.loads(line) for line in open('excavators.json')]
frame = DataFrame(records)
frame.c = frame.c.astype(float64)
frame.groupby(['q', frame['auction']]).size().unstack().fillna(0).plot(kind='bar', stacked=True)

# %% [markdown]
# ## Range (5.7, 12]t

# %%
frame_ex = (frame[frame.c > 5.7])[frame.c <= 12]
frame_ex.groupby(['q', frame_ex['auction']]).size().unstack().fillna(0).sort(axis=1).plot(kind='bar', stacked=True)

# %% [markdown]
# ## Range (12, 18]t

# %%
frame_ex = (frame[frame.c > 12])[frame.c <= 18]
frame_ex.groupby(['q', frame_ex['auction']]).size().unstack().fillna(0).plot(kind='bar', stacked=True)

# %% [markdown]
# ## Range (18, 25]t

# %%
frame_ex = (frame[frame.c > 18])[frame.c <= 25]
frame_ex.groupby(['q', frame_ex['auction']]).size().unstack().fillna(0).plot(kind='bar', stacked=True)

# %% [markdown]
# ## Range (25, 40]t

# %%
frame_ex = (frame[frame.c > 25])[frame.c <= 40]
frame_ex.groupby(['q', frame_ex['auction']]).size().unstack().fillna(0).plot(kind='bar', stacked=True)

# %% [markdown]
# ## Range (40, 100]t

# %%
frame_ex = (frame[frame.c > 40])[frame.c <= 100]
frame_ex.groupby(['q', frame_ex['auction']]).size().unstack().fillna(0).plot(kind='bar', stacked=True)
